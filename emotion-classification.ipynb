# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Loading-Libraries" data-toc-modified-id="Loading-Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Loading Libraries</strong></a></span></li><li><span><a href="#-Analysizing-Dataset--" data-toc-modified-id="-Analysizing-Dataset---2"><span class="toc-item-num">2&nbsp;&nbsp;</span> Analysizing Dataset  </a></span><ul class="toc-item"><li><span><a href="#Emotion-Distribution-Table" data-toc-modified-id="Emotion-Distribution-Table-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><strong>Emotion Distribution Table</strong></a></span></li><li><span><a href="#Bar-chart-of-the-train-and-test-data" data-toc-modified-id="Bar-chart-of-the-train-and-test-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span><strong>Bar chart of the train and test data</strong></a></span></li><li><span><a href="#Show-a-batch-of-images" data-toc-modified-id="Show-a-batch-of-images-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span><strong>Show a batch of images</strong></a></span></li><li><span><a href="#Problem" data-toc-modified-id="Problem-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span><strong>Problem</strong></a></span></li></ul></li><li><span><a href="#-Data-Preprocessing--" data-toc-modified-id="-Data-Preprocessing---3"><span class="toc-item-num">3&nbsp;&nbsp;</span> Data Preprocessing  </a></span><ul class="toc-item"><li><span><a href="#Data-Augmentation" data-toc-modified-id="Data-Augmentation-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><strong>Data Augmentation</strong></a></span></li><li><span><a href="#Oversampling(doesn't-work)" data-toc-modified-id="Oversampling(doesn't-work)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><strong>Oversampling(doesn't work)</strong></a></span></li><li><span><a href="#Class_weight(doesn't-work)" data-toc-modified-id="Class_weight(doesn't-work)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span><strong>Class_weight(doesn't work)</strong></a></span></li></ul></li><li><span><a href="#-Building-CNN-Model-and-Results--" data-toc-modified-id="-Building-CNN-Model-and-Results---4"><span class="toc-item-num">4&nbsp;&nbsp;</span> Building CNN Model and Results  </a></span><ul class="toc-item"><li><span><a href="#CNN-Model" data-toc-modified-id="CNN-Model-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><strong>CNN Model</strong></a></span></li><li><span><a href="#Specifying-CNN-Callbacks" data-toc-modified-id="Specifying-CNN-Callbacks-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><strong>Specifying CNN Callbacks</strong></a></span></li><li><span><a href="#CNN-Training" data-toc-modified-id="CNN-Training-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span><strong>CNN Training</strong></a></span></li><li><span><a href="#Visualising-CNN-Loss-and-Accuracy" data-toc-modified-id="Visualising-CNN-Loss-and-Accuracy-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span><strong>Visualising CNN Loss and Accuracy</strong></a></span></li><li><span><a href="#Evaluating-CNN-Model" data-toc-modified-id="Evaluating-CNN-Model-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span><strong>Evaluating CNN Model</strong></a></span></li><li><span><a href="#NN-Confusion-Matrix" data-toc-modified-id="NN-Confusion-Matrix-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span><strong>NN Confusion Matrix</strong></a></span></li></ul></li><li><span><a href="#-Tansfer-Learning-and-Results--" data-toc-modified-id="-Tansfer-Learning-and-Results---5"><span class="toc-item-num">5&nbsp;&nbsp;</span> Tansfer Learning and Results  </a></span><ul class="toc-item"><li><span><a href="#ResNet50V2-Model" data-toc-modified-id="ResNet50V2-Model-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span><strong>ResNet50V2 Model</strong></a></span></li><li><span><a href="#Fine-Tuning-ResNet50V2" data-toc-modified-id="Fine-Tuning-ResNet50V2-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span><strong>Fine-Tuning ResNet50V2</strong></a></span></li><li><span><a href="#Customed-Output-Layer" data-toc-modified-id="Customed-Output-Layer-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span><strong>Customed Output Layer</strong></a></span></li><li><span><a href="#Specifying-ResNet-Callbacks" data-toc-modified-id="Specifying-ResNet-Callbacks-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span><strong>Specifying ResNet Callbacks</strong></a></span></li><li><span><a href="#ResNet-Training" data-toc-modified-id="ResNet-Training-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span><strong>ResNet Training</strong></a></span></li><li><span><a href="#Visualising-ResNet-Loss-and-Accuracy" data-toc-modified-id="Visualising-ResNet-Loss-and-Accuracy-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span><strong>Visualising ResNet Loss and Accuracy</strong></a></span></li><li><span><a href="#Evaluating-ResNet50V2" data-toc-modified-id="Evaluating-ResNet50V2-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span><strong>Evaluating ResNet50V2</strong></a></span></li><li><span><a href="#ResNet-Confusion-Matrix" data-toc-modified-id="ResNet-Confusion-Matrix-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span><strong>ResNet Confusion Matrix</strong></a></span></li></ul></li><li><span><a href="#-Visualizing-Predictions--" data-toc-modified-id="-Visualizing-Predictions---6"><span class="toc-item-num">6&nbsp;&nbsp;</span> Visualizing Predictions  </a></span><ul class="toc-item"><li><span><a href="#5Shuffling-Test-Data" data-toc-modified-id="5Shuffling-Test-Data-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span><strong>5Shuffling Test Data</strong></a></span></li><li><span><a href="#CNN-Predictions" data-toc-modified-id="CNN-Predictions-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span><strong>CNN Predictions</strong></a></span></li><li><span><a href="#ResNet50V2-Predictions" data-toc-modified-id="ResNet50V2-Predictions-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span><strong>ResNet50V2 Predictions</strong></a></span></li></ul></li><li><span><a href="#Save-Models" data-toc-modified-id="Save-Models-7"><span class="toc-item-num">7&nbsp;&nbsp;</span><strong>Save Models</strong></a></span></li></ul></div>

# %% [markdown]
# # Classifying emotions using images
#
#
#
#
# &emsp;**Group 5 final project**
#
# - **Group member:**: Zelong Tan, Jingtao Yu, Yewen Li, Zinian Wang, Yuanjun He
#
# <hr style="height:2.4pt">

# %% [markdown]
# ## **Loading Libraries**

# %%
#load the basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import os
import tensorflow as tf
import keras
import cv2

#load libraries for data preprocessing
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

#load libraries for building CNN
from tensorflow.keras.layers import *
from tensorflow.keras import layers , models, optimizers
from tensorflow.keras.models import Sequential, Model

#load libraries for ResNet transfer learning
from tensorflow.keras.applications import ResNet50V2

#load libraries for callbacks
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

#load libraries for visualizing
from tensorflow.keras.utils import plot_model

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#EFF8D0">
# <h2> Analysizing Dataset  </h2>
#
# - **Dataset Discription:** In this section, we are going to visaulize the emotion classes distribution to help us preprocess the data.
#   - 48x48 pixel grayscale images of faces
#   - automatically registered to be centred
#   - occupy a similar amount of space
#   - 22,968 examples in the training set and 1,432 examples in the public test set.

# %%
# define a  function to caculate the number of each emotion classes
train_dir = './train/'
test_dir = './test/'

def Classes_Count( path, name):
    Classes_Dict = {}
    
    for Class in os.listdir(path):
        
        Full_Path = path + Class
        Classes_Dict[Class] = len(os.listdir(Full_Path))
        
    df = pd.DataFrame(Classes_Dict, index=[name])
    
    return df

Train_Count = Classes_Count(train_dir, 'Train').transpose().sort_values(by="Train", ascending=False)
Test_Count = Classes_Count(test_dir, 'Test').transpose().sort_values(by="Test", ascending=False)

# %% [markdown]
# ### **Emotion Distribution Table**

# %%
pd.concat([Train_Count,Test_Count] , axis=1)
# Out:
#           Train  Test
# happy      7215  1774
# neutral    4965  1233
# sad        4830  1247
# fear       4097  1024
# angry      3995   958
# surprise   3171   831
# disgust     436   111

# %% [markdown]
# **Explanation:** The data set is unbalanced

# %% [markdown]
# ### **Bar chart of the train and test data**

# %%
Train_Count.plot(kind='barh')
plt.title('Train Data Distribution')
plt.xlabel('Number of images')
plt.ylabel('Emotions')
plt.show()

# %% [markdown]
# **Explanation:** The number of happy faces is about 20 times tha disgust faces in training data set.

# %%
Test_Count.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Explanation:** The number of happy faces is about 17 times tha disgust faces in test data set.

# %% [markdown]
# ### **Show a batch of images**

# %%
plt.style.use('default')
plt.figure(figsize = (25, 8))
image_count = 1
BASE_URL = './train/'

for directory in os.listdir(BASE_URL):
    if directory[0] != '.':
        for i, file in enumerate(os.listdir(BASE_URL + directory)):
            if i == 1:
                break
            else:
                fig = plt.subplot(1, 7, image_count)
                image_count += 1
                image = cv2.imread(BASE_URL + directory + '/' + file)
                plt.imshow(image)
                plt.title(directory, fontsize = 20)

# %% [markdown]
# **Explanation:** Show how the images in the data set look like.

# %% [markdown]
# ### **Problem**
#
#
# We notes that the dataset is **unbalanced**. The number of happy images is alomost 20 times than the disgust in train dataset and 10 times in test dataset. We are going to try  to deal with it in the preprocessing section.

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#EFF8D0">
# <h2> Data Preprocessing  </h2>
#
# - **Data Augmentation:** Data augmentation can increase the size and diversity of the training data, reduce overfitting, and improve the generalization and robustness of the model
#   - rotation_range=10
#   - arotation_range=10
#   - width_shift_range=0.1
#   - height_shift_range=0.1
#   - horizontal_flip=True
#   - fill_mode='nearest
# - **Other failed attempts:** Class imbalance we find in last part may cause classifiers to be biased towards the majority classes and fail to learn proper features for the minority classes, resulting in poor performance
#   - Oversampling(SMOTE)
#   - Class_weight

# %% [markdown]
# ###   **Data Augmentation**

# %%
img_shape = 48
batch_size = 64
train_data_path = './train/'
test_data_path = './test/'

# %%
#using data generators to generate batches of images 
train_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
        # Data Augmentation
        rotation_range=10,
        zoom_range=0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,                                        
        fill_mode='nearest',
    )


test_preprocessor = ImageDataGenerator(
    rescale = 1 / 255.,
)

train_data = train_preprocessor.flow_from_directory(
    train_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size,
    subset='training', 
)


test_data = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### **Oversampling(doesn't work)**

# %%
# from imblearn.over_sampling import SMOTE
# # 将 train_data 转换为 numpy 数组
# x_train = []
# y_train = []
# for i in range(len(train_data)):
#     x, y = train_data.next()
#     x_train.append(x)
#     y_train.append(y)
# x_train = np.concatenate(x_train)
# y_train = np.concatenate(y_train)
# print(x_train.shape)
# # use SMOTE to oversample
# smote = SMOTE(sampling_strategy='auto', random_state=42)
# x_smote, y_smote = smote.fit_resample(x_train.reshape(28709, 3*48*48), y_train) # flatten x_train
# x_smote = x_smote.reshape(50505, 48, 48,3) # 还原 x_smote
# train_data_smote = train_preprocessor.flow(
#     x_smote,
#     y_smote,
#     batch_size=batch_size,
#     shuffle=True,
# )

# %% [markdown]
# ### **Class_weight(doesn't work)**

# %%
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight(
#            'balanced',
#             np.unique(train_data.classes), 
#             train_data.classes)
# class_weights = dict(enumerate(class_weights)

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#EFF8D0">
# <h2> Building CNN Model and Results  </h2>
#
#
#
# - **Customed CNN:** we concatenates 3 CNNs and deisgn a output layer.
#   - epochs=50
#   - train_acc=0.6597
#   - validation_acc=0.6655
# - **Callbacks:** We uses Early_Stopping and Reducing_LearningRate to avoid overfitting
#   - Early_Stopping：patience = 15
#   - Reducing_LR：patience = 2

# %% [markdown]
# ### **CNN Model**

# %%
def Create_CNN_Model():
    
    model = Sequential()
    
    #CNN1
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=(img_shape, img_shape, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(64,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN2
    model.add(Conv2D(64, (3,3), activation='relu', ))
    model.add(BatchNormalization())
    model.add(Conv2D(128,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN3
    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    
    #Output
    model.add(Flatten())
    
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(7,activation='softmax'))
    
    
    return model

# %%
CNN_Model = Create_CNN_Model()

CNN_Model.summary()

CNN_Model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 46, 46, 32)        896
#
#  batch_normalization (BatchN  (None, 46, 46, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 21, 21, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 128)       0
#
# ...

# %% [markdown]
# ### **Specifying CNN Callbacks**

# %%
# Create Callback Checkpoint
checkpoint_path = "CNN_Model_Checkpoint"

Checkpoint = ModelCheckpoint(checkpoint_path, monitor="val_accuracy", save_best_only=True)

# Create Early Stopping Callback to monitor the accuracy
Early_Stopping = EarlyStopping(monitor = 'val_accuracy', patience = 15, restore_best_weights = True, verbose=1)

# Create ReduceLROnPlateau Callback to reduce overfitting by decreasing learning rate
Reducing_LR = tf.keras.callbacks.ReduceLROnPlateau( monitor='val_loss',
                                                  factor=0.2,
                                                  patience=2,
#                                                   min_lr=0.000005,
                                                  verbose=1)

callbacks = [Early_Stopping, Reducing_LR]

steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %% [markdown]
# ### **CNN Training**

# %%
CNN_history = CNN_Model.fit( train_data , validation_data= test_data , epochs=50, batch_size= batch_size,
                            callbacks=callbacks, steps_per_epoch= steps_per_epoch, validation_steps=validation_steps)
# Out:
# Epoch 1/50
# 448/448 [==============================] - 43s 76ms/step - loss: 2.0516 - accuracy: 0.2104 - val_loss: 1.8143 - val_accuracy: 0.2447 - lr: 0.0010
# Epoch 2/50
# 448/448 [==============================] - 31s 68ms/step - loss: 1.7541 - accuracy: 0.2919 - val_loss: 1.6877 - val_accuracy: 0.3298 - lr: 0.0010
# Epoch 3/50
# 448/448 [==============================] - 30s 66ms/step - loss: 1.6228 - accuracy: 0.3625 - val_loss: 1.5544 - val_accuracy: 0.3956 - lr: 0.0010
# Epoch 4/50
# 448/448 [==============================] - 34s 75ms/step - loss: 1.5006 - accuracy: 0.4170 - val_loss: 1.3756 - val_accuracy: 0.4692 - lr: 0.0010
# Epoch 5/50
# 448/448 [==============================] - 31s 69ms/step - loss: 1.4127 - accuracy: 0.4603 - val_loss: 1.2654 - val_accuracy: 0.5151 - lr: 0.0010
# Epoch 6/50
# 448/448 [==============================] - 29s 66ms/step - loss: 1.3549 - accuracy: 0.4782 - val_loss: 1.2962 - val_accuracy: 0.4914 - lr: 0.0010
# Epoch 7/50
# ...

# %% [markdown]
# ### **Visualising CNN Loss and Accuracy**

# %%
def plot_curves(history):

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]

    epochs = range(len(history.history["loss"]))

    plt.figure(figsize=(15,5))

    #plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label = "training_loss")
    plt.plot(epochs, val_loss, label = "val_loss")
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.legend()

    #plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label = "training_accuracy")
    plt.plot(epochs, val_accuracy, label = "val_accuracy")
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.legend()
  
  #plt.tight_layout()

# %%
plot_curves(CNN_history)

# %% [markdown]
# **Explanation:** CNN model demonstrated a decline in training and validation losses, along with an uptick in accuracies, signifying effective learning.  However, the CNN model was more consistent between training and validation metrics, indicating better generalization.

# %% [markdown]
# ### **Evaluating CNN Model**

# %%
CNN_Score = CNN_Model.evaluate(test_data)

print("    Test Loss: {:.5f}".format(CNN_Score[0]))
print("Test Accuracy: {:.2f}%".format(CNN_Score[1] * 100))
# Out:
# 113/113 [==============================] - 2s 20ms/step - loss: 0.9048 - accuracy: 0.6654
#     Test Loss: 0.90478
# Test Accuracy: 66.54%

# %% [markdown]
# ###   **NN Confusion Matrix**

# %%
CNN_Predictions = CNN_Model.predict(test_data)

# Choosing highest probalbilty class in every prediction 
CNN_Predictions = np.argmax(CNN_Predictions, axis=1)

# %%
#get the relationship between classes name and numbers
test_data.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

fig, ax= plt.subplots(figsize=(15,10))

cm=confusion_matrix(test_data.labels, CNN_Predictions)

sns.heatmap(cm, annot=True, fmt='g', ax=ax)

ax.set_xlabel('Predicted labels',fontsize=15, fontweight='bold')
ax.set_ylabel('True labels', fontsize=15, fontweight='bold')
ax.set_title('CNN Confusion Matrix', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'CNN Confusion Matrix')

# %% [markdown]
# **Explanation:** CNN excels particularly on labels 3(happy) and 6(surprise), especially in terms of F1 score.  CNN also demonstrates better generalization, as its performance is more consistent between training and validation.  Moreover, by gradually adjusting the learning rate, CNN shows further improvement in performance.

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#EFF8D0">
# <h2> Tansfer Learning and Results  </h2>
#
#
#
# &emsp;  **ResNet50V2** Model For Transfer Learning
#
#
# - **ResNet50V2:** we concatenates ResNet50V2 and  a customed output layer.
#   - Freeze all layers except last 50
#   - epochs=30
#   - train_acc=0.7506
#   - validation_acc=0.6882
#
# - **Callbacks:** We uses Early_Stopping and Reducing_LearningRate to avoid overfitting
#   - Early_Stopping：patience = 15
#   - Reducing_LR：patience = 2
#
#
#
#
#
#
# **Note:**
# The input shape of ResNet isn't 48 * 48 but 224 * 224, so we have to load data again.

# %% [markdown]
# ### **ResNet50V2 Model**

# %%
# specifing new image shape for resnet
img_shape = 224
batch_size = 64
train_data_path = './train/'
test_data_path = './test/'

# %%
#load data again
train_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
        rotation_range=10,
        zoom_range=0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,                                        
        fill_mode='nearest',
    )


test_preprocessor = ImageDataGenerator(
    rescale = 1 / 255.,
)

train_data = train_preprocessor.flow_from_directory(
    train_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb',
    shuffle=True,
    batch_size=batch_size,
    subset='training', 
)

test_data = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### **Fine-Tuning ResNet50V2**

# %%
# 224,224,3
ResNet50V2 = tf.keras.applications.ResNet50V2(input_shape=(224, 224, 3),
                                               include_top= False,
                                               weights='imagenet'
                                               )

#ResNet50V2.summary()

# %%
# Freezing all layers except last 50

ResNet50V2.trainable = True

for layer in ResNet50V2.layers[:-50]:
    layer.trainable = False

# %% [markdown]
# ### **Customed Output Layer**

# %%
def Create_ResNet50V2_Model():

    model = Sequential([
                      ResNet50V2,
                      Dropout(.25),
                      BatchNormalization(),
                      Flatten(),
                      Dense(64, activation='relu'),
                      BatchNormalization(),
                      Dropout(.5),
                      Dense(7,activation='softmax')
                    ])
    return model

# %%
ResNet50V2_Model = Create_ResNet50V2_Model()

ResNet50V2_Model.summary()

ResNet50V2_Model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  dropout (Dropout)           (None, 7, 7, 2048)        0
#
#  batch_normalization (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 64)                6422592
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 7)                 455
#
# ...
# Total params: 29,996,295
# Trainable params: 22,779,527
# Non-trainable params: 7,216,768
# _________________________________________________________________

# %% [markdown]
# ### **Specifying ResNet Callbacks**

# %%
# Create Callback Checkpoint
checkpoint_path = "ResNet50V2_Model_Checkpoint"

Checkpoint = ModelCheckpoint(checkpoint_path, monitor="val_accuracy", save_best_only=True)

# Create Early Stopping Callback to monitor the accuracy
Early_Stopping = EarlyStopping(monitor = 'val_accuracy', patience = 7, restore_best_weights = True, verbose=1)

# Create ReduceLROnPlateau Callback to reduce overfitting by decreasing learning
Reducing_LR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                  factor=0.2,
                                                  patience=2,
#                                                   min_lr=0.00005,
                                                  verbose=1)

callbacks = [Early_Stopping, Reducing_LR]

steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %% [markdown]
# ### **ResNet Training**

# %%
ResNet50V2_history = ResNet50V2_Model.fit(train_data ,validation_data = test_data , epochs=30, batch_size=batch_size,
                                         callbacks = callbacks, steps_per_epoch=steps_per_epoch, validation_steps=validation_steps)
# Out:
# Epoch 1/30
# 448/448 [==============================] - 216s 458ms/step - loss: 1.5588 - accuracy: 0.4666 - val_loss: 1.2718 - val_accuracy: 0.5294 - lr: 0.0010
# Epoch 2/30
# 448/448 [==============================] - 227s 506ms/step - loss: 1.2312 - accuracy: 0.5562 - val_loss: 1.1616 - val_accuracy: 0.5956 - lr: 0.0010
# Epoch 3/30
# 448/448 [==============================] - 239s 532ms/step - loss: 1.1250 - accuracy: 0.5969 - val_loss: 1.1726 - val_accuracy: 0.6006 - lr: 0.0010
# Epoch 4/30
# 448/448 [==============================] - ETA: 0s - loss: 1.1122 - accuracy: 0.5980
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 448/448 [==============================] - 224s 499ms/step - loss: 1.1122 - accuracy: 0.5980 - val_loss: 1.1735 - val_accuracy: 0.5652 - lr: 0.0010
# Epoch 5/30
# 448/448 [==============================] - 230s 513ms/step - loss: 0.9902 - accuracy: 0.6430 - val_loss: 0.9499 - val_accuracy: 0.6511 - lr: 2.0000e-04
# ...

# %% [markdown]
# ### **Visualising ResNet Loss and Accuracy**

# %%
plot_curves(ResNet50V2_history)

# %% [markdown]
# **Explanation:** In ResNet model, a plateau in validation loss pointed to potential overfitting, suggesting that transfer learning did not yield the anticipated benefits in this specific scenario.

# %% [markdown]
# ### **Evaluating ResNet50V2**

# %%
ResNet50V2_Score = ResNet50V2_Model.evaluate(test_data)

print("    Test Loss: {:.5f}".format(ResNet50V2_Score[0]))
print("Test Accuracy: {:.2f}%".format(ResNet50V2_Score[1] * 100))
# Out:
# 113/113 [==============================] - 13s 112ms/step - loss: 0.8954 - accuracy: 0.6767
#     Test Loss: 0.89540
# Test Accuracy: 67.67%

# %% [markdown]
# ### **ResNet Confusion Matrix**

# %%
ResNet50V2_Predictions = ResNet50V2_Model.predict(test_data)

# Choosing highest probalbilty class in every prediction 
ResNet50V2_Predictions = np.argmax(ResNet50V2_Predictions, axis=1)

# %%
fig , ax= plt.subplots(figsize=(15,10))

cm=confusion_matrix(test_data.labels, ResNet50V2_Predictions)

sns.heatmap(cm, annot=True, fmt='g', ax=ax)

ax.set_xlabel('Predicted labels',fontsize=15, fontweight='bold')
ax.set_ylabel('True labels', fontsize=15, fontweight='bold')
ax.set_title('ResNet50V2 Confusion Matrix', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'ResNet50V2 Confusion Matrix')

# %% [markdown]
# **Explanation:** ResNet performs better on specific labels, such as 2(fear) and 5(sad).  Particularly, ResNet's F1 scores are higher than CNN's on these labels.  This indicates that even if ResNet might not be optimal overall, it still has room for improvement on these specific labels.

# %% [markdown]
# <div class="alert alert-block alert-danger" style="color:black;background-color:#EFF8D0">
# <h2> Visualizing Predictions  </h2>
#
# - **Goal:** Test our models in a direct way.
# - Display 10 random pictures from the dataset with their labels.

# %% [markdown]
# ### **5Shuffling Test Data**

# %%
Emotion_Classes = ['Angry', 
                  'Disgust', 
                  'Fear', 
                  'Happy', 
                  'Neutral', 
                  'Sad', 
                  'Surprise']

# %%
# Shuffling Test Data to show diffrent classes
test_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
    )

test_generator = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(48,48),
    color_mode="rgb",
    shuffle=True,
    batch_size=batch_size,
)
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### **CNN Predictions**

# %%
# Display 10 random pictures from the dataset with their labels

Random_batch = np.random.randint(0, len(test_generator) - 1)

Random_Img_Index = np.random.randint(0, batch_size - 1 , 10)

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(25, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):

    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]

    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]])

    Model_Prediction = np.argmax(CNN_Model.predict( tf.expand_dims(Random_Img, axis=0) , verbose=0))

    ax.imshow(Random_Img)

    if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction]:
          color = "green"
    else:
          color = "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)
plt.show()
plt.tight_layout()

# %% [markdown]
# **Explanation:** The CNN model have a good performance in predicting new image.

# %% [markdown]
# ### **ResNet50V2 Predictions**

# %%
# Shuffling Test Data to show diffrent classes
test_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
    )

test_generator = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(224,224),
    color_mode="rgb",
    shuffle=True,
    batch_size=batch_size,
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
# Display 10 random pictures from the dataset with their labels

Random_batch = np.random.randint(0, len(test_generator) - 1)

Random_Img_Index = np.random.randint(0, batch_size - 1 , 10)

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(25, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):

    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]

    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]])

    Model_Prediction = np.argmax(ResNet50V2_Model.predict( tf.expand_dims(Random_Img, axis=0) , verbose=0))

    ax.imshow(Random_Img)

    if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction]:
          color = "green"
    else:
          color = "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)
plt.show()
plt.tight_layout()

# %% [markdown]
# **Explanation:** The CNN model have a good performance in predicting new image.

# %% [markdown]
# ## **Save Models**

# %%
CNN_Model.save("CNN_Model.h5")

ResNet50V2_Model.save("ResNet50V2_Model.h5")
